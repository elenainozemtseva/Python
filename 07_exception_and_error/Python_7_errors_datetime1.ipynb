# %% [markdown]
# # Обработка ошибок
# 1. Текст ошибки указывается в последней строчке
# 2. Все что перед ней - место, где ошибка произошла
# 3. Есть встроенные типы ошибок, но можно создавать и свои

# %% [markdown]
# Некоторые типы ошибок из документации (точнее [перевода](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)):
# - ZeroDivisionError - деление на ноль
# - ImportError - не удалось импортирование модуля или его атрибута (надо установить эту библиотеку)
# - IndexError - индекс не входит в диапазон элементов.
# - KeyError - несуществующий ключ (в словаре, множестве или другом объекте)
# - MemoryError - недостаточно памяти
# - SyntaxError - синтаксическая ошибка (вы опечатались или не закрыли скобку)
# - TypeError - операция применена к объекту несоответствующего типа
# - ValueError - функция получает аргумент правильного типа, но некорректного значения
# - Warning - предупреждение (текст на красном фоне в юпитере это предупреждение, а не ошибка)

# %%
# эту строку можно перевести в число
some_num = '123'

# %%
float(some_num)
# Out:
# 123.0

# %%
# а эту уже нет (по крайней мере в десятичном счислении)
ups = '123a'

# %%
# ValueError - тип ошибки, далее пояснение что произошло
# ----> 1 float(ups) - в каком месте кода произошла ошибка
float(ups)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b5e45a6d52d0> in <module>
#       1 # ValueError - тип ошибки, далее пояснение что произошло
#       2 # ----> 1 float(ups) - в каком месте кода произошла ошибка
# ----> 3 float(ups)
#
# ValueError: could not convert string to float: '123a'

# %% [markdown]
# Пример ошибки внутри функции

# %%
def square_sum(*args):
    total_sum = 0
    for arg in args:
        total_sum += arg**2
    
    return total_sum

# %%
square_sum(1, 2, 3)
# Out:
# 14

# %%
# пытаемся применить к операцию возведения в квадрат к строке
# ----> 1 square_sum(1, 2, '3') - в какой функции произошла ошибка
# ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка

square_sum(1, 2, '3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7189647907b6> in <module>
#       3 # ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка
#       4
# ----> 5 square_sum(1, 2, '3')
#
# <ipython-input-5-45a18875b039> in square_sum(*args)
#       2     total_sum = 0
#       3     for arg in args:
# ----> 4         total_sum += arg**2
#       5
#       6     return total_sum
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ## Как сделать, чтобы цикл с расчетом не падал каждый раз

# %%
try:
    # ваш код, где может произойти ошибка
    float('123a')

except:
    # код, который выполняется в случае ошибки
# Out:
#   File "<ipython-input-8-75e5ffc2ac13>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
data = ['90', '60', '90', '240tot']
total_sum = 0

for num in data:
    try:
        total_sum += float(num)

    except:
        print('Ошибка в данных: {}'.format(num))
    
print('Итого', total_sum)
# Out:
# Ошибка в данных: 240tot
# Итого 240.0

# %% [markdown]
# Как сохранить всю информацию об ошибке?

# %%
# полная версия traceback
import traceback

try:
    float('123fff')

except Exception:
    print(traceback.print_exc())
    
print('Проехали')
# Out:
# None
# Проехали
# Traceback (most recent call last):
#   File "<ipython-input-11-aec2760d579a>", line 5, in <module>
#     float('123fff')
# ValueError: could not convert string to float: '123fff'

# %% [markdown]
# ### Упражнение
# Создайте словарь stats = {'monday': 100, 'tuesday': 200}.
#
# Какой тип ошибки вызовет обращение stats['wednesday']?

# %%
 stats = {'monday': 100, 'tuesday': 200}

# %%
stats['wednesday']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d047c4841875> in <module>
# ----> 1 stats['wednesday']
#
# KeyError: 'wednesday'

# %% [markdown]
# ### Блок finally

# %%
try:
    print(stats["wednesday"])
    
except IndexError:
    print("Ошибка индекса")
    
except KeyError:
    print("Ошибка ключа")
    print(1/0)
    
finally:
    print('Эта строчка будет выполнена всегда')
# Out:
# Ошибка ключа
# Эта строчка будет выполнена всегда
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f6fe70bb823a> in <module>
#       1 try:
# ----> 2     print(stats["wednesday"])
#       3
#
# KeyError: 'wednesday'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-f6fe70bb823a> in <module>
#       7 except KeyError:
#       8     print("Ошибка ключа")
# ----> 9     print(1/0)
#      10
#      11 finally:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Более жизненный пример

# %%
with open('real_data.txt', 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# 05.10.16 23:18	1010	20,2
# 09.10.2016T 21:40:00	1036	15,6
# 05.10.16 3:23	1041
# 05.10.16 23:19	1041
# 01.10.16 4:57	1042	14,8
# 01.10.16 23:29	1042	14,4
# 03.10.16 20:20	1042	14
# 04.10.16 0:35	1042	20
# 04.10.16 13:46	1042	16,2
# 04.10.16 17:34	1042	11
# 05.10.16 15:15	1042	10800000
# 06.10.16 20:45	1042	22,6
# 07.10.16 2:54	1042	22,4
# 07.10.16 5:02	1042	24,4
# 07.10.16 6:35	1042	16,6
# 08.10.2016T 16:46:00	1042	8,6
# 01.10.16 13:39	1047
# 05.10.16 21:41	1047
# 07.10.16 9:59	1052	24
# 08.10.2016T 19:36:00	1052	18,8
# 04.10.16 11:12	1057
# 09.10.2016T 2:47:00	1057
# 09.10.2016T 16:27:00	1062	11,2
# 05.10.16 4:38	1067	19
# 04.10.16 9:56	1078	23,4
# 04.10.16 14:36	1085	17
# 05.10.16 16:41	1096	20,8
# 01.10.16 11:55	1098	15,6
# 01.10.16 14:16	1100
# 02.10.16 1:39	1100
# 02.10.16 2:49	1100
# 02.10.16 13:05	1100
# 03.10.16 4:04	1100
# 03.10.16 6:58	1100
# 03.10.16 15:01	1100
# 04.10.16 23:43	1100
# 05.10.16 5:46	1100
# 06.10.16 0:31	1100
# 06.10.16 9:25	1100
# 08.10.2016T 15:15:00	1100
# 07.10.16 9:06	1105	16,2
# 01.10.16 4:30	1108	17,8
# 01.10.16 18:16	1108	18,8
# 02.10.16 2:58	1108	20000000
# 02.10.16 6:01	1108	21
# 02.10.16 20:03	1108	16,6
# 04.10.16 2:56	1108	20
# 04.10.16 6:57	1108	19,8
# 06.10.16 6:46	1108	16,8
# 09.10.2016T 8:33:00	1108	24000000
# 08.10.2016T 8:02:00	1111	12
# 05.10.16 5:25	1112	10,2
# 09.10.2016T 0:03:00	1112	24
# 06.10.16 10:09	1113	15,8
# 09.10.2016T 12:09:00	1113	22
# 05.10.16 18:00	1114	17,4
# 06.10.16 17:58	1114	14,8
# 05.10.16 23:19	1116	20
# 01.10.16 23:13	1118	11,6
# 09.10.2016T 21:14:00	1118	20
# 05.10.16 16:30	1123	16
# 06.10.16 5:27	1123	11,2
# 01.10.16 17:46	1128	12,2
# 04.10.16 5:00	1134
# 06.10.16 12:01	1134
# 01.10.16 15:58	1135
# 02.10.16 3:19	1135
# 02.10.16 19:24	1135
# 04.10.16 10:40	1135
# 06.10.16 6:06	1135
# 06.10.16 16:08	1135
# 08.10.2016T 0:31:00	1135
# 08.10.2016T 10:16:00	1135
# 08.10.2016T 23:10:00	1135
# 01.10.16 22:28	1136	21,6
# 03.10.16 23:03	1136	17,4
# 03.10.16 8:06	1140	22
# 04.10.16 10:01	1140	22
# 01.10.16 16:53	1141	16
# 05.10.16 3:31	1145	16
# 06.10.16 4:00	1145	20
# 02.10.16 8:08	1149	10
# 07.10.16 16:12	1149	21,2
# 08.10.2016T 6:55:00	1149	30,4
# 08.10.2016T 22:55:00	1149	18800000
# 09.10.2016T 4:10:00	1149	14
# 09.10.2016T 10:26:00	1149	22
# 09.10.2016T 22:22:00	1149	16
# 07.10.16 6:57	1150	12,6
# 02.10.16 12:03	1154	13,4
# 04.10.16 22:51	1154	13,6
# 04.10.16 9:28	1159	10,2
# 04.10.16 13:34	1159	17,4
# 08.10.2016T 9:43:00	1164	22,4
# 07.10.16 14:57	1167	11,4
# 07.10.16 20:25	1175	14
# 06.10.16 12:48	1181	22,4
# 07.10.16 9:54	1182	18
# 10.10.16 2:35	1182	17
# 04.10.16 13:49	1193	24800000
# 09.10.2016T 20:49:00	1193	16,6
# 01.10.16 5:12	1198	17,8
# 06.10.16 7:52	1198	9
# 06.10.16 5:15	1201	10,6
# 05.10.16 13:55	1203
# 06.10.16 5:56	1203
# 01.10.16 16:10	1207	16,6
# 02.10.16 1:24	1207	24,2
# 02.10.16 21:17	1207	20,4
# 03.10.16 16:08	1207	25,6
# 04.10.16 17:29	1207	19,8
# 05.10.16 1:39	1207	16,4
# 05.10.16 6:33	1207	16,2
# 05.10.16 18:57	1207	17
# 05.10.16 20:51	1207	16,8
# 07.10.16 8:55	1207	19,8
# 07.10.16 17:40	1207	15,6
# 08.10.2016T 23:36:00	1207	19,2
# 09.10.2016T 10:25:00	1207	23,2
# 09.10.2016T 21:04:00	1207	10,8
# 04.10.16 7:38	1208	24,4
# 09.10.2016T 14:53:00	1208	13,4
# 05.10.16 17:15	1209	12
# 03.10.16 6:16	1213	18,6
# 06.10.16 10:04	1213	16,6
# 01.10.16 16:52	1218	12200000
# 09.10.2016T 19:10:00	1218	22400000
# 02.10.16 8:42	1219	15,4
# 03.10.16 19:32	1223	17,2
# 06.10.16 22:11	1223	17600000
# 08.10.2016T 15:18:00	1224	16,4
# 01.10.16 4:41	1226
# 03.10.16 9:32	1226
# 07.10.16 18:32	1228	18,8
# 08.10.2016T 13:21:00	1228	17,6
# 03.10.16 15:47	1230	20,6
# 01.10.16 9:02	1233
# 01.10.16 10:27	1233
# 02.10.16 22:01	1236	17,4
# 05.10.16 5:27	1238	13,6
# 09.10.2016T 14:43:00	1238	17,6
# 04.10.16 22:25	1242	18,4
# 06.10.16 4:54	1243	20,4
# 06.10.16 14:28	1243	20
# 01.10.16 4:27	1246	17,8
# 02.10.16 4:27	1246
# 02.10.16 8:45	1246
# 02.10.16 16:58	1246
# 02.10.16 17:30	1246
# 02.10.16 19:46	1246
# 03.10.16 2:05	1246
# 03.10.16 2:57	1246
# 03.10.16 7:19	1246
# 03.10.16 12:15	1246
# 03.10.16 14:58	1246
# 03.10.16 19:43	1246
# 04.10.16 7:27	1246
# 04.10.16 9:08	1246
# 04.10.16 13:52	1246
# 04.10.16 16:34	1246
# 05.10.16 0:27	1246
# 05.10.16 6:36	1246
# 05.10.16 12:59	1246
# 05.10.16 16:52	1246
# 05.10.16 17:26	1246
# 06.10.16 6:48	1246
# 08.10.2016T 2:53:00	1246
# 10.10.16 0:59	1246
# 01.10.16 16:30	1248	13,2
# 01.10.16 21:06	1248	28,8
# 02.10.16 7:12	1252	22
# 04.10.16 13:51	1252	15,6
# 01.10.16 12:36	1253	13,6
# 04.10.16 17:11	1253	8,6
# 02.10.16 16:22	1258	22
# 08.10.2016T 19:34:00	1258	20
# 02.10.16 10:36	1263	12,6
# 03.10.16 6:10	1263	18
# 02.10.16 21:42	1267
# 04.10.16 9:02	1267
# 04.10.16 12:10	1267
# 04.10.16 15:40	1267
# 04.10.16 18:37	1267
# 04.10.16 21:29	1267
# 05.10.16 21:11	1267
# 05.10.16 22:09	1267
# 06.10.16 3:58	1267
# 06.10.16 11:16	1267
# 06.10.16 19:20	1267
# 07.10.16 10:18	1267
# 08.10.2016T 18:18:00	1267
# 09.10.2016T 4:41:00	1267
# 09.10.2016T 9:13:00	1267
# 09.10.2016T 15:37:00	1267
# 09.10.2016T 18:56:00	1267
# 05.10.16 2:48	1268	16,4
# 07.10.16 19:36	1268	16
# 02.10.16 14:12	1269	22
# 07.10.16 3:29	1270	21,8
# 01.10.16 8:56	1273	14,6
# 08.10.2016T 13:49:00	1273	22
# 07.10.16 6:00	1274	25
# 04.10.16 13:47	1278	15,6
# 07.10.16 6:42	1278	17,8
# 08.10.2016T 3:24:00	1279	14,8
# 03.10.16 1:03	1281	18,2
# 02.10.16 6:11	1283	12,6
# 02.10.16 19:24	1283	11,8
# 07.10.16 13:37	1288	16
# 08.10.2016T 19:46:00	1288	30,4
# 07.10.16 2:41	1291	13,4
# 01.10.16 17:29	1293	18,4
# 02.10.16 20:12	1293	20
# 02.10.16 23:36	1294	17
# 07.10.16 10:32	1296	26
# 03.10.16 20:41	1298	21
# 03.10.16 22:35	1298	19,4
# 05.10.16 12:19	1298	16
# 02.10.16 11:43	1300	12,8
# 03.10.16 23:18	1300	14
# 03.10.16 18:28	1302	21800000
# 02.10.16 8:06	1303	11,8
# 06.10.16 6:23	1303	25,8
# 03.10.16 10:42	1308	18
# 06.10.16 18:52	1308	10,2
# 06.10.16 16:16	1313	12
# 08.10.2016T 18:12:00	1313	13,8
# 02.10.16 14:04	1315	16,6
# 03.10.16 14:10	1318
# 03.10.16 18:15	1318
# 03.10.16 18:27	1318
# 04.10.16 17:09	1318
# 05.10.16 11:07	1318
# 06.10.16 1:46	1318
# 06.10.16 22:29	1318
# 07.10.16 0:44	1318
# 07.10.16 10:17	1318
# 07.10.16 11:29	1318
# 08.10.2016T 23:18:00	1318
# 09.10.2016T 1:37:00	1318
# 09.10.2016T 7:48:00	1318
# 09.10.2016T 22:27:00	1318
# 06.10.16 17:08	1320	18
# 09.10.2016T 2:35:00	1323	16
# 09.10.2016T 10:08:00	1323	28,6
# 05.10.16 7:29	1328	18,4
# 05.10.16 11:58	1328	18,8
# 03.10.16 0:36	1330	17,8
# 09.10.2016T 2:08:00	1331	16,8
# 03.10.16 2:19	1332	19,4
# 04.10.16 22:01	1333	20
# 08.10.2016T 3:48:00	1334	16
# 03.10.16 1:32	1343	22
# 08.10.2016T 4:34:00	1350	12800000
# 04.10.16 4:09	1351	20
# 06.10.16 19:09	1353	17,4
# 03.10.16 1:30	1354	15,6
# 02.10.16 23:30	1355	22
# 08.10.2016T 6:50:00	1359	14,4
# 02.10.16 13:33	1362	12,2
# 05.10.16 21:36	1363	12,2
# 04.10.16 22:06	1364	20
# 01.10.16 5:29	1366	13000000
# 07.10.16 9:40	1367	22,4
# 04.10.16 7:31	1371	13,6
# 04.10.16 1:36	1372	30,4
# 07.10.16 17:25	1374	12,4
# 05.10.16 23:06	1377	16
# 06.10.16 14:29	1380	30,4
# 09.10.2016T 4:55:00	1382	23,2
# 05.10.16 21:24	1383	20
# 05.10.16 8:14	1386	12,6
# 03.10.16 11:43	1387	14,6
# 01.10.16 6:21	1388	11,8
# 03.10.16 6:03	1392	20,2
# 06.10.16 5:34	1393	10
# 04.10.16 23:55	1394	12,8
# 05.10.16 5:01	1397	20,6
# 05.10.16 22:54	1398	18
# 01.10.16 17:01	1424
# 03.10.16 6:50	1424
# 04.10.16 5:27	1424
# 04.10.16 16:14	1424
# 04.10.16 18:21	1424
# 05.10.16 23:33	1424
# 06.10.16 7:27	1424
# 07.10.16 3:01	1424
# 07.10.16 16:08	1424
# 07.10.16 16:12	1424
# 08.10.2016T 12:41:00	1424
# 08.10.2016T 15:26:00	1424
# 08.10.2016T 17:21:00	1424
# 09.10.2016T 8:00:00	1424
# 10.10.16 1:24	1424

# %% [markdown]
# Чем прекрасен этот файл:
# 1. Даты имеют разный формат: за 8 и 9 октября формат с "09.10.2016 21:40" сменился на "09.10.2016T 21:40:00" (добавилась буква T и секунды). Разработчики объяснили этот тем, что сбились настройки после обновления одной из баз данных.
# 2. У покупок некоторых пользователей неизвестно значение выручки, из-за чего количество столбцов в строке уменьшается на один.
# 3. У некоторых строк реальная сумма покупки умножена на миллион. Так иногда действительно делают, чтобы избежать дробных чисел и работать только с целыми.

# %% [markdown]
# ### Упражнение
# Посчитайте сумму выручки из третьего столбца. Пока не обращайте внимания на помноженную на миллион выручку.

# %%
 with open('real_data.txt', 'r') as f:
    total_sum = 0
    for line in f:
        try:
            line_s = line.strip().split()
            if ',' in line_s[3]:               
                total_sum = total_sum + float(line_s[3].replace(',','.'))
            else:
                total_sum = total_sum + float(line_s[3])
        except:
            print(f'Error in line {line}')
        finally:
            print(line.strip().split())
    print(total_sum)
# Out:
# ['05.10.16', '23:18', '1010', '20,2']
# ['09.10.2016T', '21:40:00', '1036', '15,6']
# Error in line 05.10.16 3:23	1041
#
# ['05.10.16', '3:23', '1041']
# Error in line 05.10.16 23:19	1041
#
# ['05.10.16', '23:19', '1041']
# ['01.10.16', '4:57', '1042', '14,8']
# ['01.10.16', '23:29', '1042', '14,4']
# ['03.10.16', '20:20', '1042', '14']
# ['04.10.16', '0:35', '1042', '20']
# ['04.10.16', '13:46', '1042', '16,2']
# ['04.10.16', '17:34', '1042', '11']
# ['05.10.16', '15:15', '1042', '10800000']
# ['06.10.16', '20:45', '1042', '22,6']
# ['07.10.16', '2:54', '1042', '22,4']
# ['07.10.16', '5:02', '1042', '24,4']
# ['07.10.16', '6:35', '1042', '16,6']
# ['08.10.2016T', '16:46:00', '1042', '8,6']
# Error in line 01.10.16 13:39	1047
#
# ['01.10.16', '13:39', '1047']
# Error in line 05.10.16 21:41	1047
#
# ['05.10.16', '21:41', '1047']
# ['07.10.16', '9:59', '1052', '24']
# ['08.10.2016T', '19:36:00', '1052', '18,8']
# Error in line 04.10.16 11:12	1057
#
# ['04.10.16', '11:12', '1057']
# Error in line 09.10.2016T 2:47:00	1057
#
# ['09.10.2016T', '2:47:00', '1057']
# ['09.10.2016T', '16:27:00', '1062', '11,2']
# ['05.10.16', '4:38', '1067', '19']
# ['04.10.16', '9:56', '1078', '23,4']
# ['04.10.16', '14:36', '1085', '17']
# ['05.10.16', '16:41', '1096', '20,8']
# ['01.10.16', '11:55', '1098', '15,6']
# Error in line 01.10.16 14:16	1100
#
# ['01.10.16', '14:16', '1100']
# Error in line 02.10.16 1:39	1100
#
# ['02.10.16', '1:39', '1100']
# Error in line 02.10.16 2:49	1100
#
# ['02.10.16', '2:49', '1100']
# Error in line 02.10.16 13:05	1100
#
# ['02.10.16', '13:05', '1100']
# Error in line 03.10.16 4:04	1100
#
# ['03.10.16', '4:04', '1100']
# Error in line 03.10.16 6:58	1100
#
# ['03.10.16', '6:58', '1100']
# Error in line 03.10.16 15:01	1100
#
# ['03.10.16', '15:01', '1100']
# Error in line 04.10.16 23:43	1100
#
# ['04.10.16', '23:43', '1100']
# Error in line 05.10.16 5:46	1100
#
# ['05.10.16', '5:46', '1100']
# Error in line 06.10.16 0:31	1100
#
# ['06.10.16', '0:31', '1100']
# Error in line 06.10.16 9:25	1100
#
# ['06.10.16', '9:25', '1100']
# Error in line 08.10.2016T 15:15:00	1100
#
# ['08.10.2016T', '15:15:00', '1100']
# ['07.10.16', '9:06', '1105', '16,2']
# ['01.10.16', '4:30', '1108', '17,8']
# ['01.10.16', '18:16', '1108', '18,8']
# ['02.10.16', '2:58', '1108', '20000000']
# ['02.10.16', '6:01', '1108', '21']
# ['02.10.16', '20:03', '1108', '16,6']
# ['04.10.16', '2:56', '1108', '20']
# ['04.10.16', '6:57', '1108', '19,8']
# ['06.10.16', '6:46', '1108', '16,8']
# ['09.10.2016T', '8:33:00', '1108', '24000000']
# ['08.10.2016T', '8:02:00', '1111', '12']
# ['05.10.16', '5:25', '1112', '10,2']
# ['09.10.2016T', '0:03:00', '1112', '24']
# ['06.10.16', '10:09', '1113', '15,8']
# ['09.10.2016T', '12:09:00', '1113', '22']
# ['05.10.16', '18:00', '1114', '17,4']
# ['06.10.16', '17:58', '1114', '14,8']
# ['05.10.16', '23:19', '1116', '20']
# ['01.10.16', '23:13', '1118', '11,6']
# ['09.10.2016T', '21:14:00', '1118', '20']
# ['05.10.16', '16:30', '1123', '16']
# ['06.10.16', '5:27', '1123', '11,2']
# ['01.10.16', '17:46', '1128', '12,2']
# Error in line 04.10.16 5:00	1134
#
# ['04.10.16', '5:00', '1134']
# Error in line 06.10.16 12:01	1134
#
# ['06.10.16', '12:01', '1134']
# Error in line 01.10.16 15:58	1135
#
# ['01.10.16', '15:58', '1135']
# Error in line 02.10.16 3:19	1135
#
# ['02.10.16', '3:19', '1135']
# Error in line 02.10.16 19:24	1135
#
# ['02.10.16', '19:24', '1135']
# Error in line 04.10.16 10:40	1135
#
# ['04.10.16', '10:40', '1135']
# Error in line 06.10.16 6:06	1135
#
# ['06.10.16', '6:06', '1135']
# Error in line 06.10.16 16:08	1135
#
# ['06.10.16', '16:08', '1135']
# Error in line 08.10.2016T 0:31:00	1135
#
# ['08.10.2016T', '0:31:00', '1135']
# Error in line 08.10.2016T 10:16:00	1135
#
# ['08.10.2016T', '10:16:00', '1135']
# Error in line 08.10.2016T 23:10:00	1135
#
# ['08.10.2016T', '23:10:00', '1135']
# ['01.10.16', '22:28', '1136', '21,6']
# ['03.10.16', '23:03', '1136', '17,4']
# ['03.10.16', '8:06', '1140', '22']
# ['04.10.16', '10:01', '1140', '22']
# ['01.10.16', '16:53', '1141', '16']
# ['05.10.16', '3:31', '1145', '16']
# ['06.10.16', '4:00', '1145', '20']
# ['02.10.16', '8:08', '1149', '10']
# ['07.10.16', '16:12', '1149', '21,2']
# ['08.10.2016T', '6:55:00', '1149', '30,4']
# ['08.10.2016T', '22:55:00', '1149', '18800000']
# ['09.10.2016T', '4:10:00', '1149', '14']
# ['09.10.2016T', '10:26:00', '1149', '22']
# ['09.10.2016T', '22:22:00', '1149', '16']
# ['07.10.16', '6:57', '1150', '12,6']
# ['02.10.16', '12:03', '1154', '13,4']
# ['04.10.16', '22:51', '1154', '13,6']
# ['04.10.16', '9:28', '1159', '10,2']
# ['04.10.16', '13:34', '1159', '17,4']
# ['08.10.2016T', '9:43:00', '1164', '22,4']
# ['07.10.16', '14:57', '1167', '11,4']
# ['07.10.16', '20:25', '1175', '14']
# ['06.10.16', '12:48', '1181', '22,4']
# ['07.10.16', '9:54', '1182', '18']
# ['10.10.16', '2:35', '1182', '17']
# ['04.10.16', '13:49', '1193', '24800000']
# ['09.10.2016T', '20:49:00', '1193', '16,6']
# ['01.10.16', '5:12', '1198', '17,8']
# ['06.10.16', '7:52', '1198', '9']
# ['06.10.16', '5:15', '1201', '10,6']
# Error in line 05.10.16 13:55	1203
#
# ['05.10.16', '13:55', '1203']
# Error in line 06.10.16 5:56	1203
#
# ['06.10.16', '5:56', '1203']
# ['01.10.16', '16:10', '1207', '16,6']
# ['02.10.16', '1:24', '1207', '24,2']
# ['02.10.16', '21:17', '1207', '20,4']
# ['03.10.16', '16:08', '1207', '25,6']
# ['04.10.16', '17:29', '1207', '19,8']
# ['05.10.16', '1:39', '1207', '16,4']
# ['05.10.16', '6:33', '1207', '16,2']
# ['05.10.16', '18:57', '1207', '17']
# ['05.10.16', '20:51', '1207', '16,8']
# ['07.10.16', '8:55', '1207', '19,8']
# ['07.10.16', '17:40', '1207', '15,6']
# ['08.10.2016T', '23:36:00', '1207', '19,2']
# ['09.10.2016T', '10:25:00', '1207', '23,2']
# ['09.10.2016T', '21:04:00', '1207', '10,8']
# ['04.10.16', '7:38', '1208', '24,4']
# ['09.10.2016T', '14:53:00', '1208', '13,4']
# ['05.10.16', '17:15', '1209', '12']
# ['03.10.16', '6:16', '1213', '18,6']
# ['06.10.16', '10:04', '1213', '16,6']
# ['01.10.16', '16:52', '1218', '12200000']
# ['09.10.2016T', '19:10:00', '1218', '22400000']
# ['02.10.16', '8:42', '1219', '15,4']
# ['03.10.16', '19:32', '1223', '17,2']
# ['06.10.16', '22:11', '1223', '17600000']
# ['08.10.2016T', '15:18:00', '1224', '16,4']
# Error in line 01.10.16 4:41	1226
#
# ['01.10.16', '4:41', '1226']
# Error in line 03.10.16 9:32	1226
#
# ['03.10.16', '9:32', '1226']
# ['07.10.16', '18:32', '1228', '18,8']
# ['08.10.2016T', '13:21:00', '1228', '17,6']
# ['03.10.16', '15:47', '1230', '20,6']
# Error in line 01.10.16 9:02	1233
#
# ['01.10.16', '9:02', '1233']
# Error in line 01.10.16 10:27	1233
#
# ['01.10.16', '10:27', '1233']
# ['02.10.16', '22:01', '1236', '17,4']
# ['05.10.16', '5:27', '1238', '13,6']
# ['09.10.2016T', '14:43:00', '1238', '17,6']
# ['04.10.16', '22:25', '1242', '18,4']
# ['06.10.16', '4:54', '1243', '20,4']
# ['06.10.16', '14:28', '1243', '20']
# ['01.10.16', '4:27', '1246', '17,8']
# Error in line 02.10.16 4:27	1246
#
# ['02.10.16', '4:27', '1246']
# Error in line 02.10.16 8:45	1246
#
# ['02.10.16', '8:45', '1246']
# Error in line 02.10.16 16:58	1246
#
# ['02.10.16', '16:58', '1246']
# Error in line 02.10.16 17:30	1246
#
# ['02.10.16', '17:30', '1246']
# Error in line 02.10.16 19:46	1246
#
# ['02.10.16', '19:46', '1246']
# Error in line 03.10.16 2:05	1246
#
# ['03.10.16', '2:05', '1246']
# Error in line 03.10.16 2:57	1246
#
# ['03.10.16', '2:57', '1246']
# Error in line 03.10.16 7:19	1246
#
# ['03.10.16', '7:19', '1246']
# Error in line 03.10.16 12:15	1246
#
# ['03.10.16', '12:15', '1246']
# Error in line 03.10.16 14:58	1246
#
# ['03.10.16', '14:58', '1246']
# Error in line 03.10.16 19:43	1246
#
# ['03.10.16', '19:43', '1246']
# Error in line 04.10.16 7:27	1246
#
# ['04.10.16', '7:27', '1246']
# Error in line 04.10.16 9:08	1246
#
# ['04.10.16', '9:08', '1246']
# Error in line 04.10.16 13:52	1246
#
# ['04.10.16', '13:52', '1246']
# Error in line 04.10.16 16:34	1246
#
# ['04.10.16', '16:34', '1246']
# Error in line 05.10.16 0:27	1246
#
# ['05.10.16', '0:27', '1246']
# Error in line 05.10.16 6:36	1246
#
# ['05.10.16', '6:36', '1246']
# Error in line 05.10.16 12:59	1246
#
# ['05.10.16', '12:59', '1246']
# Error in line 05.10.16 16:52	1246
#
# ['05.10.16', '16:52', '1246']
# Error in line 05.10.16 17:26	1246
#
# ['05.10.16', '17:26', '1246']
# Error in line 06.10.16 6:48	1246
#
# ['06.10.16', '6:48', '1246']
# Error in line 08.10.2016T 2:53:00	1246
#
# ['08.10.2016T', '2:53:00', '1246']
# Error in line 10.10.16 0:59	1246
#
# ['10.10.16', '0:59', '1246']
# ['01.10.16', '16:30', '1248', '13,2']
# ['01.10.16', '21:06', '1248', '28,8']
# ['02.10.16', '7:12', '1252', '22']
# ['04.10.16', '13:51', '1252', '15,6']
# ['01.10.16', '12:36', '1253', '13,6']
# ['04.10.16', '17:11', '1253', '8,6']
# ['02.10.16', '16:22', '1258', '22']
# ['08.10.2016T', '19:34:00', '1258', '20']
# ['02.10.16', '10:36', '1263', '12,6']
# ['03.10.16', '6:10', '1263', '18']
# Error in line 02.10.16 21:42	1267
#
# ['02.10.16', '21:42', '1267']
# Error in line 04.10.16 9:02	1267
#
# ['04.10.16', '9:02', '1267']
# Error in line 04.10.16 12:10	1267
#
# ['04.10.16', '12:10', '1267']
# Error in line 04.10.16 15:40	1267
#
# ['04.10.16', '15:40', '1267']
# Error in line 04.10.16 18:37	1267
#
# ['04.10.16', '18:37', '1267']
# Error in line 04.10.16 21:29	1267
#
# ['04.10.16', '21:29', '1267']
# Error in line 05.10.16 21:11	1267
#
# ['05.10.16', '21:11', '1267']
# Error in line 05.10.16 22:09	1267
#
# ['05.10.16', '22:09', '1267']
# Error in line 06.10.16 3:58	1267
#
# ['06.10.16', '3:58', '1267']
# Error in line 06.10.16 11:16	1267
#
# ['06.10.16', '11:16', '1267']
# Error in line 06.10.16 19:20	1267
#
# ['06.10.16', '19:20', '1267']
# Error in line 07.10.16 10:18	1267
#
# ['07.10.16', '10:18', '1267']
# Error in line 08.10.2016T 18:18:00	1267
#
# ['08.10.2016T', '18:18:00', '1267']
# Error in line 09.10.2016T 4:41:00	1267
#
# ['09.10.2016T', '4:41:00', '1267']
# Error in line 09.10.2016T 9:13:00	1267
#
# ['09.10.2016T', '9:13:00', '1267']
# Error in line 09.10.2016T 15:37:00	1267
#
# ['09.10.2016T', '15:37:00', '1267']
# Error in line 09.10.2016T 18:56:00	1267
#
# ['09.10.2016T', '18:56:00', '1267']
# ['05.10.16', '2:48', '1268', '16,4']
# ['07.10.16', '19:36', '1268', '16']
# ['02.10.16', '14:12', '1269', '22']
# ['07.10.16', '3:29', '1270', '21,8']
# ['01.10.16', '8:56', '1273', '14,6']
# ['08.10.2016T', '13:49:00', '1273', '22']
# ['07.10.16', '6:00', '1274', '25']
# ['04.10.16', '13:47', '1278', '15,6']
# ['07.10.16', '6:42', '1278', '17,8']
# ['08.10.2016T', '3:24:00', '1279', '14,8']
# ['03.10.16', '1:03', '1281', '18,2']
# ['02.10.16', '6:11', '1283', '12,6']
# ['02.10.16', '19:24', '1283', '11,8']
# ['07.10.16', '13:37', '1288', '16']
# ['08.10.2016T', '19:46:00', '1288', '30,4']
# ['07.10.16', '2:41', '1291', '13,4']
# ['01.10.16', '17:29', '1293', '18,4']
# ['02.10.16', '20:12', '1293', '20']
# ['02.10.16', '23:36', '1294', '17']
# ['07.10.16', '10:32', '1296', '26']
# ['03.10.16', '20:41', '1298', '21']
# ['03.10.16', '22:35', '1298', '19,4']
# ['05.10.16', '12:19', '1298', '16']
# ['02.10.16', '11:43', '1300', '12,8']
# ['03.10.16', '23:18', '1300', '14']
# ['03.10.16', '18:28', '1302', '21800000']
# ['02.10.16', '8:06', '1303', '11,8']
# ['06.10.16', '6:23', '1303', '25,8']
# ['03.10.16', '10:42', '1308', '18']
# ['06.10.16', '18:52', '1308', '10,2']
# ['06.10.16', '16:16', '1313', '12']
# ['08.10.2016T', '18:12:00', '1313', '13,8']
# ['02.10.16', '14:04', '1315', '16,6']
# Error in line 03.10.16 14:10	1318
#
# ['03.10.16', '14:10', '1318']
# Error in line 03.10.16 18:15	1318
#
# ['03.10.16', '18:15', '1318']
# Error in line 03.10.16 18:27	1318
#
# ['03.10.16', '18:27', '1318']
# Error in line 04.10.16 17:09	1318
#
# ['04.10.16', '17:09', '1318']
# Error in line 05.10.16 11:07	1318
#
# ['05.10.16', '11:07', '1318']
# Error in line 06.10.16 1:46	1318
#
# ['06.10.16', '1:46', '1318']
# Error in line 06.10.16 22:29	1318
#
# ['06.10.16', '22:29', '1318']
# Error in line 07.10.16 0:44	1318
#
# ['07.10.16', '0:44', '1318']
# Error in line 07.10.16 10:17	1318
#
# ['07.10.16', '10:17', '1318']
# Error in line 07.10.16 11:29	1318
#
# ['07.10.16', '11:29', '1318']
# Error in line 08.10.2016T 23:18:00	1318
#
# ['08.10.2016T', '23:18:00', '1318']
# Error in line 09.10.2016T 1:37:00	1318
#
# ['09.10.2016T', '1:37:00', '1318']
# Error in line 09.10.2016T 7:48:00	1318
#
# ['09.10.2016T', '7:48:00', '1318']
# Error in line 09.10.2016T 22:27:00	1318
#
# ['09.10.2016T', '22:27:00', '1318']
# ['06.10.16', '17:08', '1320', '18']
# ['09.10.2016T', '2:35:00', '1323', '16']
# ['09.10.2016T', '10:08:00', '1323', '28,6']
# ['05.10.16', '7:29', '1328', '18,4']
# ['05.10.16', '11:58', '1328', '18,8']
# ['03.10.16', '0:36', '1330', '17,8']
# ['09.10.2016T', '2:08:00', '1331', '16,8']
# ['03.10.16', '2:19', '1332', '19,4']
# ['04.10.16', '22:01', '1333', '20']
# ['08.10.2016T', '3:48:00', '1334', '16']
# ['03.10.16', '1:32', '1343', '22']
# ['08.10.2016T', '4:34:00', '1350', '12800000']
# ['04.10.16', '4:09', '1351', '20']
# ['06.10.16', '19:09', '1353', '17,4']
# ['03.10.16', '1:30', '1354', '15,6']
# ['02.10.16', '23:30', '1355', '22']
# ['08.10.2016T', '6:50:00', '1359', '14,4']
# ['02.10.16', '13:33', '1362', '12,2']
# ['05.10.16', '21:36', '1363', '12,2']
# ['04.10.16', '22:06', '1364', '20']
# ['01.10.16', '5:29', '1366', '13000000']
# ['07.10.16', '9:40', '1367', '22,4']
# ['04.10.16', '7:31', '1371', '13,6']
# ['04.10.16', '1:36', '1372', '30,4']
# ['07.10.16', '17:25', '1374', '12,4']
# ['05.10.16', '23:06', '1377', '16']
# ['06.10.16', '14:29', '1380', '30,4']
# ['09.10.2016T', '4:55:00', '1382', '23,2']
# ['05.10.16', '21:24', '1383', '20']
# ['05.10.16', '8:14', '1386', '12,6']
# ['03.10.16', '11:43', '1387', '14,6']
# ['01.10.16', '6:21', '1388', '11,8']
# ['03.10.16', '6:03', '1392', '20,2']
# ['06.10.16', '5:34', '1393', '10']
# ['04.10.16', '23:55', '1394', '12,8']
# ['05.10.16', '5:01', '1397', '20,6']
# ['05.10.16', '22:54', '1398', '18']
# Error in line 01.10.16 17:01	1424
#
# ['01.10.16', '17:01', '1424']
# Error in line 03.10.16 6:50	1424
#
# ['03.10.16', '6:50', '1424']
# Error in line 04.10.16 5:27	1424
#
# ['04.10.16', '5:27', '1424']
# Error in line 04.10.16 16:14	1424
#
# ['04.10.16', '16:14', '1424']
# Error in line 04.10.16 18:21	1424
#
# ['04.10.16', '18:21', '1424']
# Error in line 05.10.16 23:33	1424
#
# ['05.10.16', '23:33', '1424']
# Error in line 06.10.16 7:27	1424
#
# ['06.10.16', '7:27', '1424']
# Error in line 07.10.16 3:01	1424
#
# ['07.10.16', '3:01', '1424']
# Error in line 07.10.16 16:08	1424
#
# ['07.10.16', '16:08', '1424']
# Error in line 07.10.16 16:12	1424
#
# ['07.10.16', '16:12', '1424']
# Error in line 08.10.2016T 12:41:00	1424
#
# ['08.10.2016T', '12:41:00', '1424']
# Error in line 08.10.2016T 15:26:00	1424
#
# ['08.10.2016T', '15:26:00', '1424']
# Error in line 08.10.2016T 17:21:00	1424
#
# ['08.10.2016T', '17:21:00', '1424']
# Error in line 09.10.2016T 8:00:00	1424
#
# ['09.10.2016T', '8:00:00', '1424']
# Error in line 10.10.16 1:24	1424
# ['10.10.16', '1:24', '1424']
# 198203147.8000001

# %%
 with open('real_data.txt', 'r') as f:
    total_sum = 0
    s = 0
    for line in f:
        line_s = line.strip().split('\t')
        #print(line_s)
        try:
            total_sum += float(line_s[2].replace(',','.'))
            
#             if ',' in line_s[2]:               
#                 total_sum = total_sum + float(line_s[2].replace(',','.'))
#             else:
#                 total_sum = total_sum + float(line_s[2])
        except:
            s += s
            #print(f'Error in line {line}')
#         finally:
#             print(line.strip().split())
    print(total_sum)
# Out:
# 198203147.8000001

# %% [markdown]
# # Даты

# %%
# иногда импортируют так
import datetime

# %%
# можно и так
import datetime as dt

# %%
# у нас будет вариант покороче (но это не одно и то же)
from datetime import datetime

# %%
date_string = '09.05.2018  09:00'

# %%
# сейчас date_string это просто строка
type(date_string)
# Out:
# str

# %%
datetime.strptime('09.05.2018 09:00', '%d.%m.%Y %H:%M')
# Out:
# datetime.datetime(2018, 5, 9, 9, 0)

# %%
# https://docs.python.org/3/library/datetime.html

date_datetime = datetime.strptime( date_string, '%d.%m.%Y %H:%M' )
date_datetime
# Out:
# datetime.datetime(2018, 5, 9, 9, 0)

# %%
# теперь можем работать с датами
type(date_datetime)
# Out:
# datetime.datetime

# %%
# получить номер года и часа
date_datetime.year, date_datetime.hour
# Out:
# (2018, 9)

# %%
# день недели
date_datetime.weekday()
# Out:
# 2

# %%
# сегодня
datetime.now()
# Out:
# datetime.datetime(2020, 5, 4, 16, 33, 55, 34718)

# %% [markdown]
# ### Упражнение
# С помощью метода datetime.strptime переведите строку 'May 25 2017 5:00AM' в формат datetime.

# %%
dt_str = 'May 25 2017 5:00AM' 
dt = datetime.strptime(dt_str,'%B %d %Y %I:%M%p')
dt
# Out:
# datetime.datetime(2017, 5, 25, 5, 0)

# %% [markdown]
# ### Прибавление интервала к датам

# %%
from datetime import timedelta

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
type(start_date)
# Out:
# str

# %%
start_date_datetime = datetime.strptime(start_date, '%Y-%m-%d')
start_date_datetime
# Out:
# datetime.datetime(2018, 1, 1, 0, 0)

# %%
start_date_datetime + timedelta(days=1)
# Out:
# datetime.datetime(2018, 1, 2, 0, 0)

# %%
start_date_datetime + timedelta(days=-7, minutes=-1)
# Out:
# datetime.datetime(2017, 12, 24, 23, 59)

# %% [markdown]
# ### Упражнение
# Дана дата в формате '2018-09-01T09:30:00'. Прибавьте к ней 12 часов 15минут и 3 секунды.

# %%
from datetime import timedelta
dt = datetime.strptime('2018-09-01T09:30:00', '%Y-%m-%dT%H:%M:%S')

# %%
dt2 = dt + timedelta(hours=12,minutes=15,seconds=3)

# %%
datetime.strftime(dt2,'%Y-%m-%dT%H:%M:%S')
# Out:
# '2018-09-01T21:45:03'

# %% [markdown]
# ### Перевод обратно в строку

# %%
date = datetime(2018, 9, 1)
date

# %%
date.strftime('%Y-%m-%d')

# %%
date.strftime('%B %d %Y %I:%M%p')

# %%
datetime.now().strftime('%Y-%m-01')

# %%
# как получить первый день месяца

date.strftime('%Y-%m-01')

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
start_date, end_date

# %%
start_date_dt = datetime.strptime(start_date, '%Y-%m-%d')
end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

print(start_date_dt, end_date_dt)

# %%
i = 0

while i < 10:
    # ...
    i += 1
    print(i)

# %%
current_dt = start_date_dt

while current_dt <= end_date_dt:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
current_dt = start_date_dt

while current_dt.strftime('%Y-%m-%d') <= end_date:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
# можно и с помощью list comprehension
[(start_date_dt + timedelta(days=x)).strftime('%Y-%m-%d') for x in range(10)]

# %% [markdown]
# ### Упражнение
# Напишите алгоритм, который "пробегает" период 1 до 7 сентября по часам. Формат вывода '06.01.2018 23:00:00'.

# %%
from datetime import timedelta
dt_start = datetime.strptime('01.09.2020 00:00:00','%d.%m.%Y %H:%M:%S')
dt_end = datetime.strptime('07.09.2020 23:59:59','%d.%m.%Y %H:%M:%S')

# %%
current_dt = dt_start
while current_dt < dt_end:
    print(datetime.strftime(current_dt,'%d.%m.%Y %H:%M:%S'))
    current_dt += timedelta(hours=1)
# Out:
# 01.09.2020 00:00:00
# 01.09.2020 01:00:00
# 01.09.2020 02:00:00
# 01.09.2020 03:00:00
# 01.09.2020 04:00:00
# 01.09.2020 05:00:00
# 01.09.2020 06:00:00
# 01.09.2020 07:00:00
# 01.09.2020 08:00:00
# 01.09.2020 09:00:00
# 01.09.2020 10:00:00
# 01.09.2020 11:00:00
# 01.09.2020 12:00:00
# 01.09.2020 13:00:00
# 01.09.2020 14:00:00
# 01.09.2020 15:00:00
# 01.09.2020 16:00:00
# 01.09.2020 17:00:00
# 01.09.2020 18:00:00
# 01.09.2020 19:00:00
# 01.09.2020 20:00:00
# 01.09.2020 21:00:00
# 01.09.2020 22:00:00
# 01.09.2020 23:00:00
# 02.09.2020 00:00:00
# 02.09.2020 01:00:00
# 02.09.2020 02:00:00
# 02.09.2020 03:00:00
# 02.09.2020 04:00:00
# 02.09.2020 05:00:00
# 02.09.2020 06:00:00
# 02.09.2020 07:00:00
# 02.09.2020 08:00:00
# 02.09.2020 09:00:00
# 02.09.2020 10:00:00
# 02.09.2020 11:00:00
# 02.09.2020 12:00:00
# 02.09.2020 13:00:00
# 02.09.2020 14:00:00
# 02.09.2020 15:00:00
# 02.09.2020 16:00:00
# 02.09.2020 17:00:00
# 02.09.2020 18:00:00
# 02.09.2020 19:00:00
# 02.09.2020 20:00:00
# 02.09.2020 21:00:00
# 02.09.2020 22:00:00
# 02.09.2020 23:00:00
# 03.09.2020 00:00:00
# 03.09.2020 01:00:00
# 03.09.2020 02:00:00
# 03.09.2020 03:00:00
# 03.09.2020 04:00:00
# 03.09.2020 05:00:00
# 03.09.2020 06:00:00
# 03.09.2020 07:00:00
# 03.09.2020 08:00:00
# 03.09.2020 09:00:00
# 03.09.2020 10:00:00
# 03.09.2020 11:00:00
# 03.09.2020 12:00:00
# 03.09.2020 13:00:00
# 03.09.2020 14:00:00
# 03.09.2020 15:00:00
# 03.09.2020 16:00:00
# 03.09.2020 17:00:00
# 03.09.2020 18:00:00
# 03.09.2020 19:00:00
# 03.09.2020 20:00:00
# 03.09.2020 21:00:00
# 03.09.2020 22:00:00
# 03.09.2020 23:00:00
# 04.09.2020 00:00:00
# 04.09.2020 01:00:00
# 04.09.2020 02:00:00
# 04.09.2020 03:00:00
# 04.09.2020 04:00:00
# 04.09.2020 05:00:00
# 04.09.2020 06:00:00
# 04.09.2020 07:00:00
# 04.09.2020 08:00:00
# 04.09.2020 09:00:00
# 04.09.2020 10:00:00
# 04.09.2020 11:00:00
# 04.09.2020 12:00:00
# 04.09.2020 13:00:00
# 04.09.2020 14:00:00
# 04.09.2020 15:00:00
# 04.09.2020 16:00:00
# 04.09.2020 17:00:00
# 04.09.2020 18:00:00
# 04.09.2020 19:00:00
# 04.09.2020 20:00:00
# 04.09.2020 21:00:00
# 04.09.2020 22:00:00
# 04.09.2020 23:00:00
# 05.09.2020 00:00:00
# 05.09.2020 01:00:00
# 05.09.2020 02:00:00
# 05.09.2020 03:00:00
# 05.09.2020 04:00:00
# 05.09.2020 05:00:00
# 05.09.2020 06:00:00
# 05.09.2020 07:00:00
# 05.09.2020 08:00:00
# 05.09.2020 09:00:00
# 05.09.2020 10:00:00
# 05.09.2020 11:00:00
# 05.09.2020 12:00:00
# 05.09.2020 13:00:00
# 05.09.2020 14:00:00
# 05.09.2020 15:00:00
# 05.09.2020 16:00:00
# 05.09.2020 17:00:00
# 05.09.2020 18:00:00
# 05.09.2020 19:00:00
# 05.09.2020 20:00:00
# 05.09.2020 21:00:00
# 05.09.2020 22:00:00
# 05.09.2020 23:00:00
# 06.09.2020 00:00:00
# 06.09.2020 01:00:00
# 06.09.2020 02:00:00
# 06.09.2020 03:00:00
# 06.09.2020 04:00:00
# 06.09.2020 05:00:00
# 06.09.2020 06:00:00
# 06.09.2020 07:00:00
# 06.09.2020 08:00:00
# 06.09.2020 09:00:00
# 06.09.2020 10:00:00
# 06.09.2020 11:00:00
# 06.09.2020 12:00:00
# 06.09.2020 13:00:00
# 06.09.2020 14:00:00
# 06.09.2020 15:00:00
# 06.09.2020 16:00:00
# 06.09.2020 17:00:00
# 06.09.2020 18:00:00
# 06.09.2020 19:00:00
# 06.09.2020 20:00:00
# 06.09.2020 21:00:00
# 06.09.2020 22:00:00
# 06.09.2020 23:00:00
# 07.09.2020 00:00:00
# 07.09.2020 01:00:00
# 07.09.2020 02:00:00
# 07.09.2020 03:00:00
# 07.09.2020 04:00:00
# 07.09.2020 05:00:00
# 07.09.2020 06:00:00
# 07.09.2020 07:00:00
# 07.09.2020 08:00:00
# 07.09.2020 09:00:00
# 07.09.2020 10:00:00
# 07.09.2020 11:00:00
# 07.09.2020 12:00:00
# 07.09.2020 13:00:00
# 07.09.2020 14:00:00
# 07.09.2020 15:00:00
# 07.09.2020 16:00:00
# 07.09.2020 17:00:00
# 07.09.2020 18:00:00
# 07.09.2020 19:00:00
# 07.09.2020 20:00:00
# 07.09.2020 21:00:00
# 07.09.2020 22:00:00
# 07.09.2020 23:00:00

# %% [markdown]
# ### Нагрузка на систему по часам

# %%
stats = {}

with open('logs.csv', 'r') as f:
    for line in f:
        line = line.strip()
        dt = line[11:13]
        stats.setdefault(dt,0)
        stats[dt] += 1
        #print(line)
        
        #break
        
        # вычисления нагрузки на систему...
        
# результат
pr_dict = {}
t_sum = sum(stats.values())
for dt_h, kol in stats.items():
    #stats[dt_h] = kol*100)/t_sum
    zn = (kol*100)/t_sum
    pr_dict.setdefault(dt_h,zn)
pr_dict
# Out:
# {'21': 5.9,
#  '20': 6.7,
#  '23': 3.6,
#  '22': 3.7,
#  '18': 7.2,
#  '13': 5.6,
#  '11': 5.2,
#  '00': 2.2,
#  '16': 5.6,
#  '17': 5.6,
#  '15': 6.8,
#  '19': 6.3,
#  '12': 6.4,
#  '10': 7.7,
#  '01': 1.0,
#  '07': 2.2,
#  '05': 1.0,
#  '09': 3.3,
#  '06': 1.9,
#  '14': 5.7,
#  '08': 4.2,
#  '03': 0.7,
#  '02': 0.8,
#  '04': 0.7}

# %%
# а в процентном соотношении?

# %% [markdown]
# ###  Unixtime
# Количество секунд, прошедших с 1 января 1970 года по UTC

# %%
import time
from datetime import date
from datetime import datetime

# %%
d = date(2019, 3, 11)

unixtime = time.mktime(d.timetuple())
unixtime

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1552251600)

# %% [markdown]
# На практике все сложнее https://habr.com/ru/post/452584/

# %% [markdown]
# # Задача про интервалы
# Имеется список отсортированных по возрастанию целых чисел data. А также целое число n, которое лежит между минимальным и максимальным значениями из списка data. Вам необходимо определить минимальное ближайшее число к n из списка data.
#
# Пример:
# ```python
# data = [1, 7, 17, 23, 27, 35, 65]
# n = 20
# ```
#
# Ответ: 17
#
# Подобные алгоритмы используются для классификации объекта по значению одной метрики. Например, это может пригодиться для классификации учащегося по его возрасту:
# ```python
# ages = {
#     1: 'дети',
#     7: 'школьники',
#     17: 'студенты',
#     23: 'аспиранты',
#     27: 'молодые ученые',
#     35: 'преподаватели',
#     65: 'пенсионеры',
# }
# ```
#
# Итого напишите функцию, которая по списку data и числу n возвращает минимальное ближайшее к n число. Список может быть любым, поэтому не рассчитывайте на написание цепочки условий через if.
#
# Бонусные варианты:
# 1. Рассмотрите ситуацию, в которой при фиксированном списке data вам необходимо классифицировать большое количество пользователей с разными значениями n. Например, вам необходимо классифицировать базу из 100 миллионов человек по возрастам по словарю ages из примера выше. Можно ли в таком случае ускорить проход по такому числу пользователей?
#
# 2. Если вы решали основное задание перебором элементов списка data и сравнением с n, то сложность такого алгоритма O(N). Т. е. при увеличении числа элементов списка data в N раз время работы алгоритма тоже вырастет в N раз. Попробуйте ускорить этот алгоритм. Например, с помощью аналога бинарного поиска.
